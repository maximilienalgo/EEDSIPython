# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
sale_pricing = pd.read_csv("./sales_predictions.csv")
sale_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   date            object
#  1   date_block_num  int64
#  2   shop_id         int64
#  3   item_id         int64
#  4   item_price      float64
#  5   item_cnt_day    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
sale_pricing = pd.read_csv("./sales_predictions.csv")
sns.relplot(data=sale_pricing,x="date",y="item_price")

# %%
sale_pricing = pd.read_csv("./sales_predictions.csv").sample(n=50)
sns.relplot(data=sale_pricing,x="date",y="item_price")

# %%
sale_pricing = pd.read_csv("./sales_predictions.csv").sample(n=50)
g = sns.relplot(data=sale_pricing,x="date",y="item_price")
g.fig.set_size_inches(15,15)

# %%
sale_pricing = pd.read_csv("./sales_predictions.csv").sample(n=50)
sale_pricing.date = pd.to_datetime(sale_pricing.date)
g = sns.relplot(data=sale_pricing,x="date",y="item_price")
g.fig.set_size_inches(15,15)
